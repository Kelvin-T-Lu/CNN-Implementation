# %% [markdown]
# # Assignment 2 Part 2: Developing Your Own Classifier

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)

import os

os.chdir("/content/drive/MyDrive/CNN_747")
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# classifier.py			   __pycache__
# colab_setup.ipynb		   resnet101.pth
# CS747_assignment2_description.pdf  resnet50_adam.pth
# CS747_Assignment2_part1.ipynb	   resnet50_best.pth
# CS747_Assignment2_part2.ipynb	   voc_dataloader.py
# dataset				   VOCdevkit_2007
# download_data.sh		   VOCtest_06-Nov-2007.tar
# kaggle_submission.py		   VOCtrainval_06-Nov-2007.tar
# my_solution.csv

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES
from torchsummary import torchsummary

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !/usr/bin/env bash ./download_data.sh
# Out:
# --2023-02-28 17:59:07--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  24.8MB/s    in 20s
#
# 2023-02-28 17:59:27 (22.4 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]
#
# --2023-02-28 18:00:35--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  25.8MB/s    in 18s
#
# 2023-02-28 18:00:53 (23.7 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %% [markdown]
# # Part 2: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            # transforms.Resize(227),
            # transforms.CenterCrop(227),
            transforms.RandomHorizontalFlip(),
            transforms.RandomResizedCrop(227),
            transforms.ToTensor(),
            normalize
        ])

test_transform = transforms.Compose([
            # transforms.Resize(227),
            # transforms.CenterCrop(227),
            transforms.RandomResizedCrop(227),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])

ds_train = VocDataset('VOCdevkit_2007/VOC2007','train',train_transform)
ds_val = VocDataset('VOCdevkit_2007/VOC2007','val',test_transform)
ds_test = VocDataset('VOCdevkit_2007/VOC2007test','test', test_transform)


import pickle 
import pathlib

abspath = pathlib.Path("dataset/train.pickle").absolute()
pickle_out = open(str(abspath), "wb")
pickle.dump(ds_train, pickle_out)
pickle_out.close()

abspath = pathlib.Path("dataset/val.pickle").absolute()
pickle_out = open(str(abspath), "wb")
pickle.dump(ds_val, pickle_out)
pickle_out.close()

abspath = pathlib.Path("dataset/test.pickle").absolute()
pickle_out = open(str(abspath), "wb")
pickle.dump(ds_test, pickle_out)
pickle_out.close()
# Out:
# /content/drive/MyDrive/CNN_747/voc_dataloader.py:137: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(box_indices),

# %%
import pickle
train_pickle = open("dataset/train.pickle", "rb")
ds_train = pickle.load(train_pickle)

val_pickle = open("dataset/val.pickle", "rb")
ds_val = pickle.load(val_pickle)

test_pickle = open("dataset/test.pickle", "rb")
ds_test = pickle.load(test_pickle)

# %%
num_epochs = 100
test_frequency = 5
batch_size = 64

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=2)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=2)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=2)

# %%
# TODO: Run your own classifier here
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

classifier = Classifier().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
# optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.2808072566986084
# -------  Class: aeroplane        AP:   0.2577  -------
# -------  Class: bicycle          AP:   0.0861  -------
# -------  Class: bird             AP:   0.0690  -------
# -------  Class: boat             AP:   0.1286  -------
# -------  Class: bottle           AP:   0.0597  -------
# -------  Class: bus              AP:   0.0417  -------
# -------  Class: car              AP:   0.1840  -------
# -------  Class: cat              AP:   0.0942  -------
# -------  Class: chair            AP:   0.1860  -------
# -------  Class: cow              AP:   0.0238  -------
# -------  Class: diningtable      AP:   0.0863  -------
# -------  Class: dog              AP:   0.0777  -------
# -------  Class: horse            AP:   0.0765  -------
# -------  Class: motorbike        AP:   0.0507  -------
# -------  Class: person           AP:   0.4825  -------
# -------  Class: pottedplant      AP:   0.0671  -------
# -------  Class: sheep            AP:   0.0138  -------
# -------  Class: sofa             AP:   0.1114  -------
# -------  Class: train            AP:   0.0694  -------
# -------  Class: tvmonitor        AP:   0.0583  -------
# mAP: 0.1112
# Avg loss: 0.2449984572827816
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.11122684140621308
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.22269907593727112
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.21575716137886047
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.21106910705566406
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.20772162079811096
# -------  Class: aeroplane        AP:   0.3954  -------
# -------  Class: bicycle          AP:   0.1974  -------
# -------  Class: bird             AP:   0.1041  -------
# -------  Class: boat             AP:   0.1801  -------
# -------  Class: bottle           AP:   0.1049  -------
# -------  Class: bus              AP:   0.1567  -------
# -------  Class: car              AP:   0.3863  -------
# -------  Class: cat              AP:   0.1555  -------
# -------  Class: chair            AP:   0.2867  -------
# -------  Class: cow              AP:   0.0793  -------
# -------  Class: diningtable      AP:   0.1938  -------
# -------  Class: dog              AP:   0.1907  -------
# -------  Class: horse            AP:   0.1921  -------
# -------  Class: motorbike        AP:   0.2130  -------
# -------  Class: person           AP:   0.5859  -------
# -------  Class: pottedplant      AP:   0.0840  -------
# -------  Class: sheep            AP:   0.1183  -------
# -------  Class: sofa             AP:   0.1781  -------
# -------  Class: train            AP:   0.1861  -------
# -------  Class: tvmonitor        AP:   0.1198  -------
# mAP: 0.2054
# Avg loss: 0.21177499890327453
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.20542075824981562
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.20173649489879608
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.2003159075975418
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.20157663524150848
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.1972687542438507
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.19534949958324432
# -------  Class: aeroplane        AP:   0.4948  -------
# -------  Class: bicycle          AP:   0.1967  -------
# -------  Class: bird             AP:   0.1754  -------
# -------  Class: boat             AP:   0.2773  -------
# -------  Class: bottle           AP:   0.1194  -------
# -------  Class: bus              AP:   0.1892  -------
# -------  Class: car              AP:   0.4517  -------
# -------  Class: cat              AP:   0.2173  -------
# -------  Class: chair            AP:   0.3339  -------
# -------  Class: cow              AP:   0.1381  -------
# -------  Class: diningtable      AP:   0.2323  -------
# -------  Class: dog              AP:   0.2569  -------
# -------  Class: horse            AP:   0.2150  -------
# -------  Class: motorbike        AP:   0.2655  -------
# -------  Class: person           AP:   0.6721  -------
# -------  Class: pottedplant      AP:   0.1299  -------
# -------  Class: sheep            AP:   0.1432  -------
# -------  Class: sofa             AP:   0.2063  -------
# -------  Class: train            AP:   0.3492  -------
# -------  Class: tvmonitor        AP:   0.1948  -------
# mAP: 0.2629
# Avg loss: 0.2075902484357357
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.26294303158145527
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.18761473894119263
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.18785516917705536
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.18404607474803925
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.18268601596355438
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.18004414439201355
# -------  Class: aeroplane        AP:   0.5689  -------
# -------  Class: bicycle          AP:   0.2238  -------
# -------  Class: bird             AP:   0.1862  -------
# -------  Class: boat             AP:   0.3467  -------
# -------  Class: bottle           AP:   0.1308  -------
# -------  Class: bus              AP:   0.2054  -------
# -------  Class: car              AP:   0.4316  -------
# -------  Class: cat              AP:   0.2741  -------
# -------  Class: chair            AP:   0.3556  -------
# -------  Class: cow              AP:   0.1045  -------
# -------  Class: diningtable      AP:   0.2601  -------
# -------  Class: dog              AP:   0.2054  -------
# -------  Class: horse            AP:   0.3167  -------
# -------  Class: motorbike        AP:   0.2923  -------
# -------  Class: person           AP:   0.6676  -------
# -------  Class: pottedplant      AP:   0.1499  -------
# -------  Class: sheep            AP:   0.1783  -------
# -------  Class: sofa             AP:   0.2350  -------
# -------  Class: train            AP:   0.3900  -------
# -------  Class: tvmonitor        AP:   0.1900  -------
# mAP: 0.2856
# Avg loss: 0.20261211432516574
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.2856450090518125
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.17979316413402557
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.177303746342659
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.17649565637111664
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.17516057193279266
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.1777186244726181
# -------  Class: aeroplane        AP:   0.5773  -------
# -------  Class: bicycle          AP:   0.2341  -------
# -------  Class: bird             AP:   0.2070  -------
# -------  Class: boat             AP:   0.3801  -------
# -------  Class: bottle           AP:   0.1389  -------
# -------  Class: bus              AP:   0.2385  -------
# -------  Class: car              AP:   0.5017  -------
# -------  Class: cat              AP:   0.2492  -------
# -------  Class: chair            AP:   0.4052  -------
# -------  Class: cow              AP:   0.1666  -------
# -------  Class: diningtable      AP:   0.2927  -------
# -------  Class: dog              AP:   0.2446  -------
# -------  Class: horse            AP:   0.3902  -------
# -------  Class: motorbike        AP:   0.2441  -------
# -------  Class: person           AP:   0.7006  -------
# -------  Class: pottedplant      AP:   0.1340  -------
# -------  Class: sheep            AP:   0.1187  -------
# -------  Class: sofa             AP:   0.2046  -------
# -------  Class: train            AP:   0.3464  -------
# -------  Class: tvmonitor        AP:   0.2567  -------
# mAP: 0.3016
# Avg loss: 0.19640991538763047
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.3015647709122107
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.17097805440425873
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.17395837604999542
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.17024016380310059
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.17031581699848175
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.1685817539691925
# -------  Class: aeroplane        AP:   0.5798  -------
# -------  Class: bicycle          AP:   0.3079  -------
# -------  Class: bird             AP:   0.2491  -------
# -------  Class: boat             AP:   0.3075  -------
# -------  Class: bottle           AP:   0.1522  -------
# -------  Class: bus              AP:   0.2942  -------
# -------  Class: car              AP:   0.4837  -------
# -------  Class: cat              AP:   0.2816  -------
# -------  Class: chair            AP:   0.3986  -------
# -------  Class: cow              AP:   0.1134  -------
# -------  Class: diningtable      AP:   0.2827  -------
# -------  Class: dog              AP:   0.2608  -------
# -------  Class: horse            AP:   0.4322  -------
# -------  Class: motorbike        AP:   0.4011  -------
# -------  Class: person           AP:   0.6987  -------
# -------  Class: pottedplant      AP:   0.1471  -------
# -------  Class: sheep            AP:   0.1798  -------
# -------  Class: sofa             AP:   0.2727  -------
# -------  Class: train            AP:   0.4391  -------
# -------  Class: tvmonitor        AP:   0.2012  -------
# mAP: 0.3242
# Avg loss: 0.19409972354769706
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.32416831795923107
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.16886161267757416
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.1650438755750656
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.1636807918548584
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.16412587463855743
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.16182801127433777
# -------  Class: aeroplane        AP:   0.5949  -------
# -------  Class: bicycle          AP:   0.1596  -------
# -------  Class: bird             AP:   0.1754  -------
# -------  Class: boat             AP:   0.3194  -------
# -------  Class: bottle           AP:   0.1911  -------
# -------  Class: bus              AP:   0.2397  -------
# -------  Class: car              AP:   0.5362  -------
# -------  Class: cat              AP:   0.2475  -------
# -------  Class: chair            AP:   0.4251  -------
# -------  Class: cow              AP:   0.1420  -------
# -------  Class: diningtable      AP:   0.2931  -------
# -------  Class: dog              AP:   0.2517  -------
# -------  Class: horse            AP:   0.3248  -------
# -------  Class: motorbike        AP:   0.3041  -------
# -------  Class: person           AP:   0.6863  -------
# -------  Class: pottedplant      AP:   0.1480  -------
# -------  Class: sheep            AP:   0.1458  -------
# -------  Class: sofa             AP:   0.2579  -------
# -------  Class: train            AP:   0.4077  -------
# -------  Class: tvmonitor        AP:   0.2304  -------
# mAP: 0.3040
# Avg loss: 0.19691214822232722
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.3040269112101074
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.16287700831890106
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.1594800502061844
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.155906543135643
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.15697412192821503
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.1612832099199295
# -------  Class: aeroplane        AP:   0.5663  -------
# -------  Class: bicycle          AP:   0.3023  -------
# -------  Class: bird             AP:   0.2075  -------
# -------  Class: boat             AP:   0.3228  -------
# -------  Class: bottle           AP:   0.1308  -------
# -------  Class: bus              AP:   0.2559  -------
# -------  Class: car              AP:   0.4848  -------
# -------  Class: cat              AP:   0.2884  -------
# -------  Class: chair            AP:   0.4457  -------
# -------  Class: cow              AP:   0.1752  -------
# -------  Class: diningtable      AP:   0.2913  -------
# -------  Class: dog              AP:   0.2944  -------
# -------  Class: horse            AP:   0.4627  -------
# -------  Class: motorbike        AP:   0.2538  -------
# -------  Class: person           AP:   0.7265  -------
# -------  Class: pottedplant      AP:   0.1602  -------
# -------  Class: sheep            AP:   0.1700  -------
# -------  Class: sofa             AP:   0.3243  -------
# -------  Class: train            AP:   0.4513  -------
# -------  Class: tvmonitor        AP:   0.2204  -------
# mAP: 0.3267
# Avg loss: 0.19563626013696195
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.32672395298867024
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.15572483837604523
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.15357454121112823
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.15274421870708466
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.15196184813976288
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.1515040248632431
# -------  Class: aeroplane        AP:   0.6025  -------
# -------  Class: bicycle          AP:   0.3563  -------
# -------  Class: bird             AP:   0.2470  -------
# -------  Class: boat             AP:   0.3598  -------
# -------  Class: bottle           AP:   0.1439  -------
# -------  Class: bus              AP:   0.2902  -------
# -------  Class: car              AP:   0.5483  -------
# -------  Class: cat              AP:   0.2950  -------
# -------  Class: chair            AP:   0.3922  -------
# -------  Class: cow              AP:   0.1564  -------
# -------  Class: diningtable      AP:   0.3817  -------
# -------  Class: dog              AP:   0.2775  -------
# -------  Class: horse            AP:   0.4594  -------
# -------  Class: motorbike        AP:   0.3984  -------
# -------  Class: person           AP:   0.7097  -------
# -------  Class: pottedplant      AP:   0.1263  -------
# -------  Class: sheep            AP:   0.1617  -------
# -------  Class: sofa             AP:   0.2521  -------
# -------  Class: train            AP:   0.5723  -------
# -------  Class: tvmonitor        AP:   0.2868  -------
# mAP: 0.3509
# Avg loss: 0.19555043205618858
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.3508818328865097
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.1512468308210373
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.14708390831947327
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.14727963507175446
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.14358054101467133
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.14259032905101776
# -------  Class: aeroplane        AP:   0.6153  -------
# -------  Class: bicycle          AP:   0.3756  -------
# -------  Class: bird             AP:   0.2707  -------
# -------  Class: boat             AP:   0.3882  -------
# -------  Class: bottle           AP:   0.1833  -------
# -------  Class: bus              AP:   0.2440  -------
# -------  Class: car              AP:   0.5470  -------
# -------  Class: cat              AP:   0.3072  -------
# -------  Class: chair            AP:   0.4161  -------
# -------  Class: cow              AP:   0.1590  -------
# -------  Class: diningtable      AP:   0.3556  -------
# -------  Class: dog              AP:   0.2302  -------
# -------  Class: horse            AP:   0.3487  -------
# -------  Class: motorbike        AP:   0.4174  -------
# -------  Class: person           AP:   0.7186  -------
# -------  Class: pottedplant      AP:   0.1575  -------
# -------  Class: sheep            AP:   0.2257  -------
# -------  Class: sofa             AP:   0.2712  -------
# -------  Class: train            AP:   0.5749  -------
# -------  Class: tvmonitor        AP:   0.1902  -------
# mAP: 0.3498
# Avg loss: 0.20227267034351826
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.34982521359773344
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.1452118307352066
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.14366932213306427
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.1431613564491272
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.14635120332241058
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.14094987511634827
# -------  Class: aeroplane        AP:   0.6346  -------
# -------  Class: bicycle          AP:   0.4263  -------
# -------  Class: bird             AP:   0.2626  -------
# -------  Class: boat             AP:   0.3788  -------
# -------  Class: bottle           AP:   0.1795  -------
# -------  Class: bus              AP:   0.1394  -------
# -------  Class: car              AP:   0.4614  -------
# -------  Class: cat              AP:   0.3465  -------
# -------  Class: chair            AP:   0.3812  -------
# -------  Class: cow              AP:   0.1844  -------
# -------  Class: diningtable      AP:   0.3175  -------
# -------  Class: dog              AP:   0.3060  -------
# -------  Class: horse            AP:   0.4523  -------
# -------  Class: motorbike        AP:   0.4659  -------
# -------  Class: person           AP:   0.7169  -------
# -------  Class: pottedplant      AP:   0.1934  -------
# -------  Class: sheep            AP:   0.1922  -------
# -------  Class: sofa             AP:   0.2552  -------
# -------  Class: train            AP:   0.4654  -------
# -------  Class: tvmonitor        AP:   0.2544  -------
# mAP: 0.3507
# Avg loss: 0.20077211707830428
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.35069040100758675
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.14201973378658295
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.1375201791524887
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.13458864390850067
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.1333724707365036
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.13465151190757751
# -------  Class: aeroplane        AP:   0.6090  -------
# -------  Class: bicycle          AP:   0.4115  -------
# -------  Class: bird             AP:   0.3259  -------
# -------  Class: boat             AP:   0.4109  -------
# -------  Class: bottle           AP:   0.1690  -------
# -------  Class: bus              AP:   0.2653  -------
# -------  Class: car              AP:   0.5696  -------
# -------  Class: cat              AP:   0.2937  -------
# -------  Class: chair            AP:   0.4102  -------
# -------  Class: cow              AP:   0.2145  -------
# -------  Class: diningtable      AP:   0.3843  -------
# -------  Class: dog              AP:   0.2777  -------
# -------  Class: horse            AP:   0.4782  -------
# -------  Class: motorbike        AP:   0.4457  -------
# -------  Class: person           AP:   0.7568  -------
# -------  Class: pottedplant      AP:   0.1903  -------
# -------  Class: sheep            AP:   0.1722  -------
# -------  Class: sofa             AP:   0.2898  -------
# -------  Class: train            AP:   0.5519  -------
# -------  Class: tvmonitor        AP:   0.2236  -------
# mAP: 0.3725
# Avg loss: 0.1987633254379034
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.37249203333351566
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.1401507705450058
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.1342858374118805
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.1292889565229416
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.12845344841480255
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.1314125955104828
# -------  Class: aeroplane        AP:   0.6192  -------
# -------  Class: bicycle          AP:   0.3355  -------
# -------  Class: bird             AP:   0.3191  -------
# -------  Class: boat             AP:   0.3708  -------
# -------  Class: bottle           AP:   0.1750  -------
# -------  Class: bus              AP:   0.3023  -------
# -------  Class: car              AP:   0.5811  -------
# -------  Class: cat              AP:   0.3412  -------
# -------  Class: chair            AP:   0.4046  -------
# -------  Class: cow              AP:   0.2043  -------
# -------  Class: diningtable      AP:   0.2769  -------
# -------  Class: dog              AP:   0.3091  -------
# -------  Class: horse            AP:   0.3922  -------
# -------  Class: motorbike        AP:   0.3797  -------
# -------  Class: person           AP:   0.7106  -------
# -------  Class: pottedplant      AP:   0.1513  -------
# -------  Class: sheep            AP:   0.1864  -------
# -------  Class: sofa             AP:   0.2576  -------
# -------  Class: train            AP:   0.5575  -------
# -------  Class: tvmonitor        AP:   0.3115  -------
# mAP: 0.3593
# Avg loss: 0.20322780944406987
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.3592930085635124
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.13537739217281342
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.12825699150562286
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.12366656213998795
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.12767887115478516
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.12845684587955475
# -------  Class: aeroplane        AP:   0.5983  -------
# -------  Class: bicycle          AP:   0.3525  -------
# -------  Class: bird             AP:   0.2922  -------
# -------  Class: boat             AP:   0.3732  -------
# -------  Class: bottle           AP:   0.1695  -------
# -------  Class: bus              AP:   0.2882  -------
# -------  Class: car              AP:   0.5307  -------
# -------  Class: cat              AP:   0.2953  -------
# -------  Class: chair            AP:   0.4235  -------
# -------  Class: cow              AP:   0.2660  -------
# -------  Class: diningtable      AP:   0.2910  -------
# -------  Class: dog              AP:   0.3210  -------
# -------  Class: horse            AP:   0.5189  -------
# -------  Class: motorbike        AP:   0.4724  -------
# -------  Class: person           AP:   0.7641  -------
# -------  Class: pottedplant      AP:   0.1486  -------
# -------  Class: sheep            AP:   0.1374  -------
# -------  Class: sofa             AP:   0.3385  -------
# -------  Class: train            AP:   0.5740  -------
# -------  Class: tvmonitor        AP:   0.2827  -------
# mAP: 0.3719
# Avg loss: 0.19798336699604988
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.371904870450257
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.1252681314945221
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.12548501789569855
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.12648355960845947
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.12809713184833527
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.12296048551797867
# -------  Class: aeroplane        AP:   0.6032  -------
# -------  Class: bicycle          AP:   0.3639  -------
# -------  Class: bird             AP:   0.2426  -------
# -------  Class: boat             AP:   0.3849  -------
# -------  Class: bottle           AP:   0.1693  -------
# -------  Class: bus              AP:   0.3232  -------
# -------  Class: car              AP:   0.5802  -------
# -------  Class: cat              AP:   0.3623  -------
# -------  Class: chair            AP:   0.4247  -------
# -------  Class: cow              AP:   0.1774  -------
# -------  Class: diningtable      AP:   0.3451  -------
# -------  Class: dog              AP:   0.2796  -------
# -------  Class: horse            AP:   0.5296  -------
# -------  Class: motorbike        AP:   0.4838  -------
# -------  Class: person           AP:   0.7767  -------
# -------  Class: pottedplant      AP:   0.1691  -------
# -------  Class: sheep            AP:   0.1470  -------
# -------  Class: sofa             AP:   0.3144  -------
# -------  Class: train            AP:   0.5609  -------
# -------  Class: tvmonitor        AP:   0.3223  -------
# mAP: 0.3780
# Avg loss: 0.1937776893377304
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.37801953956047746
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.1270502805709839
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.12752358615398407
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.12046922743320465
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.12091932445764542
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.1186809092760086
# -------  Class: aeroplane        AP:   0.5958  -------
# -------  Class: bicycle          AP:   0.3632  -------
# -------  Class: bird             AP:   0.2611  -------
# -------  Class: boat             AP:   0.3423  -------
# -------  Class: bottle           AP:   0.1753  -------
# -------  Class: bus              AP:   0.3658  -------
# -------  Class: car              AP:   0.5700  -------
# -------  Class: cat              AP:   0.3411  -------
# -------  Class: chair            AP:   0.4412  -------
# -------  Class: cow              AP:   0.2142  -------
# -------  Class: diningtable      AP:   0.3663  -------
# -------  Class: dog              AP:   0.2912  -------
# -------  Class: horse            AP:   0.5104  -------
# -------  Class: motorbike        AP:   0.4912  -------
# -------  Class: person           AP:   0.7760  -------
# -------  Class: pottedplant      AP:   0.1355  -------
# -------  Class: sheep            AP:   0.1524  -------
# -------  Class: sofa             AP:   0.3093  -------
# -------  Class: train            AP:   0.5126  -------
# -------  Class: tvmonitor        AP:   0.2940  -------
# mAP: 0.3754
# Avg loss: 0.19502157531678677
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.3754496291436686
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.1169714480638504
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.11916691064834595
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.118405282497406
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.11647412925958633
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.1118566021323204
# -------  Class: aeroplane        AP:   0.6099  -------
# -------  Class: bicycle          AP:   0.3749  -------
# -------  Class: bird             AP:   0.2832  -------
# -------  Class: boat             AP:   0.4308  -------
# -------  Class: bottle           AP:   0.1652  -------
# -------  Class: bus              AP:   0.3413  -------
# -------  Class: car              AP:   0.6012  -------
# -------  Class: cat              AP:   0.3632  -------
# -------  Class: chair            AP:   0.4647  -------
# -------  Class: cow              AP:   0.2507  -------
# -------  Class: diningtable      AP:   0.2733  -------
# -------  Class: dog              AP:   0.2850  -------
# -------  Class: horse            AP:   0.4618  -------
# -------  Class: motorbike        AP:   0.4288  -------
# -------  Class: person           AP:   0.7569  -------
# -------  Class: pottedplant      AP:   0.2022  -------
# -------  Class: sheep            AP:   0.1550  -------
# -------  Class: sofa             AP:   0.3248  -------
# -------  Class: train            AP:   0.5384  -------
# -------  Class: tvmonitor        AP:   0.2893  -------
# mAP: 0.3800
# Avg loss: 0.2048095092177391
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.3800310001134654
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.10761922597885132
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.10824630409479141
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.10715439170598984
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.11151305586099625
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.10990341007709503
# -------  Class: aeroplane        AP:   0.6466  -------
# -------  Class: bicycle          AP:   0.4109  -------
# -------  Class: bird             AP:   0.3546  -------
# -------  Class: boat             AP:   0.4146  -------
# -------  Class: bottle           AP:   0.1534  -------
# -------  Class: bus              AP:   0.4061  -------
# -------  Class: car              AP:   0.6309  -------
# -------  Class: cat              AP:   0.2934  -------
# -------  Class: chair            AP:   0.4169  -------
# -------  Class: cow              AP:   0.1983  -------
# -------  Class: diningtable      AP:   0.3491  -------
# -------  Class: dog              AP:   0.2687  -------
# -------  Class: horse            AP:   0.5006  -------
# -------  Class: motorbike        AP:   0.5609  -------
# -------  Class: person           AP:   0.7995  -------
# -------  Class: pottedplant      AP:   0.1648  -------
# -------  Class: sheep            AP:   0.2092  -------
# -------  Class: sofa             AP:   0.2802  -------
# -------  Class: train            AP:   0.5845  -------
# -------  Class: tvmonitor        AP:   0.2521  -------
# mAP: 0.3948
# Avg loss: 0.19843845255672932
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.3947703839696336
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.10575158894062042
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.10634227842092514
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.11201129108667374
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.10606421530246735
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.10697420686483383
# -------  Class: aeroplane        AP:   0.6272  -------
# -------  Class: bicycle          AP:   0.2899  -------
# -------  Class: bird             AP:   0.2383  -------
# -------  Class: boat             AP:   0.4596  -------
# -------  Class: bottle           AP:   0.1315  -------
# -------  Class: bus              AP:   0.2744  -------
# -------  Class: car              AP:   0.6445  -------
# -------  Class: cat              AP:   0.3775  -------
# -------  Class: chair            AP:   0.4063  -------
# -------  Class: cow              AP:   0.2136  -------
# -------  Class: diningtable      AP:   0.3268  -------
# -------  Class: dog              AP:   0.3182  -------
# -------  Class: horse            AP:   0.5142  -------
# -------  Class: motorbike        AP:   0.5106  -------
# -------  Class: person           AP:   0.7652  -------
# -------  Class: pottedplant      AP:   0.1197  -------
# -------  Class: sheep            AP:   0.2311  -------
# -------  Class: sofa             AP:   0.3188  -------
# -------  Class: train            AP:   0.5664  -------
# -------  Class: tvmonitor        AP:   0.2898  -------
# mAP: 0.3812
# Avg loss: 0.2160213327035308
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.38118020139950676
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.11061978340148926
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.10538726300001144
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.10864265263080597
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.10245802253484726
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.0968688577413559
# -------  Class: aeroplane        AP:   0.6106  -------
# -------  Class: bicycle          AP:   0.3015  -------
# -------  Class: bird             AP:   0.2469  -------
# -------  Class: boat             AP:   0.4099  -------
# -------  Class: bottle           AP:   0.1778  -------
# -------  Class: bus              AP:   0.2870  -------
# -------  Class: car              AP:   0.6077  -------
# -------  Class: cat              AP:   0.3471  -------
# -------  Class: chair            AP:   0.4055  -------
# -------  Class: cow              AP:   0.2021  -------
# -------  Class: diningtable      AP:   0.3303  -------
# -------  Class: dog              AP:   0.2748  -------
# -------  Class: horse            AP:   0.5317  -------
# -------  Class: motorbike        AP:   0.4413  -------
# -------  Class: person           AP:   0.7695  -------
# -------  Class: pottedplant      AP:   0.2176  -------
# -------  Class: sheep            AP:   0.1502  -------
# -------  Class: sofa             AP:   0.3058  -------
# -------  Class: train            AP:   0.4784  -------
# -------  Class: tvmonitor        AP:   0.3373  -------
# mAP: 0.3717
# Avg loss: 0.2187756672501564
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.3716556000190244
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.09136577695608139
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.10127075016498566
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.10185962170362473
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.09609789401292801
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.09631466865539551
# -------  Class: aeroplane        AP:   0.5927  -------
# -------  Class: bicycle          AP:   0.3828  -------
# -------  Class: bird             AP:   0.2768  -------
# -------  Class: boat             AP:   0.4071  -------
# -------  Class: bottle           AP:   0.1678  -------
# -------  Class: bus              AP:   0.2813  -------
# -------  Class: car              AP:   0.5957  -------
# -------  Class: cat              AP:   0.3064  -------
# -------  Class: chair            AP:   0.3878  -------
# -------  Class: cow              AP:   0.2289  -------
# -------  Class: diningtable      AP:   0.3403  -------
# -------  Class: dog              AP:   0.2680  -------
# -------  Class: horse            AP:   0.5341  -------
# -------  Class: motorbike        AP:   0.5165  -------
# -------  Class: person           AP:   0.7665  -------
# -------  Class: pottedplant      AP:   0.1612  -------
# -------  Class: sheep            AP:   0.2003  -------
# -------  Class: sofa             AP:   0.2900  -------
# -------  Class: train            AP:   0.4938  -------
# -------  Class: tvmonitor        AP:   0.2861  -------
# mAP: 0.3742
# Avg loss: 0.21749122776091098
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.37420909998876045

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.5951  -------
# -------  Class: bicycle          AP:   0.3721  -------
# -------  Class: bird             AP:   0.3034  -------
# -------  Class: boat             AP:   0.4007  -------
# -------  Class: bottle           AP:   0.1509  -------
# -------  Class: bus              AP:   0.2944  -------
# -------  Class: car              AP:   0.6228  -------
# -------  Class: cat              AP:   0.3519  -------
# -------  Class: chair            AP:   0.4119  -------
# -------  Class: cow              AP:   0.1827  -------
# -------  Class: diningtable      AP:   0.3108  -------
# -------  Class: dog              AP:   0.2987  -------
# -------  Class: horse            AP:   0.6137  -------
# -------  Class: motorbike        AP:   0.4866  -------
# -------  Class: person           AP:   0.7806  -------
# -------  Class: pottedplant      AP:   0.2175  -------
# -------  Class: sheep            AP:   0.2101  -------
# -------  Class: sofa             AP:   0.2608  -------
# -------  Class: train            AP:   0.5006  -------
# -------  Class: tvmonitor        AP:   0.2790  -------
# mAP: 0.3822
# Avg loss: 0.21286320380675486
# 0.3822125646229452

# %%
torch.save(classifier.state_dict(), './resnet50_best.pth')
output_submission_csv('my_solution.csv', test_aps)

# %%
from torchsummary import summary

summary(classifier, (3, 227,227))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 114, 114]           9,472
#        BatchNorm2d-2         [-1, 64, 114, 114]             128
#  Convolution_Block-3         [-1, 64, 114, 114]               0
#               ReLU-4         [-1, 64, 114, 114]               0
#          MaxPool2d-5           [-1, 64, 57, 57]               0
#             Conv2d-6           [-1, 64, 57, 57]           4,160
#        BatchNorm2d-7           [-1, 64, 57, 57]             128
#  Convolution_Block-8           [-1, 64, 57, 57]               0
#               ReLU-9           [-1, 64, 57, 57]               0
#            Conv2d-10           [-1, 64, 57, 57]          36,928
#       BatchNorm2d-11           [-1, 64, 57, 57]             128
# Convolution_Block-12           [-1, 64, 57, 57]               0
#              ReLU-13           [-1, 64, 57, 57]               0
#            Conv2d-14          [-1, 256, 57, 57]          16,640
#       BatchNorm2d-15          [-1, 256, 57, 57]             512
# Convolution_Block-16          [-1, 256, 57, 57]               0
#            Conv2d-17          [-1, 256, 57, 57]          16,640
#       BatchNorm2d-18          [-1, 256, 57, 57]             512
# Convolution_Block-19          [-1, 256, 57, 57]               0
#              ReLU-20          [-1, 256, 57, 57]               0
#    Residual_Block-21          [-1, 256, 57, 57]               0
#            Conv2d-22           [-1, 64, 57, 57]          16,448
#       BatchNorm2d-23           [-1, 64, 57, 57]             128
# Convolution_Block-24           [-1, 64, 57, 57]               0
#              ReLU-25           [-1, 64, 57, 57]               0
#            Conv2d-26           [-1, 64, 57, 57]          36,928
#       BatchNorm2d-27           [-1, 64, 57, 57]             128
# Convolution_Block-28           [-1, 64, 57, 57]               0
#              ReLU-29           [-1, 64, 57, 57]               0
#            Conv2d-30          [-1, 256, 57, 57]          16,640
#       BatchNorm2d-31          [-1, 256, 57, 57]             512
# Convolution_Block-32          [-1, 256, 57, 57]               0
#              ReLU-33          [-1, 256, 57, 57]               0
#    Residual_Block-34          [-1, 256, 57, 57]               0
#            Conv2d-35           [-1, 64, 57, 57]          16,448
#       BatchNorm2d-36           [-1, 64, 57, 57]             128
# Convolution_Block-37           [-1, 64, 57, 57]               0
#              ReLU-38           [-1, 64, 57, 57]               0
#            Conv2d-39           [-1, 64, 57, 57]          36,928
#       BatchNorm2d-40           [-1, 64, 57, 57]             128
# Convolution_Block-41           [-1, 64, 57, 57]               0
#              ReLU-42           [-1, 64, 57, 57]               0
#            Conv2d-43          [-1, 256, 57, 57]          16,640
#       BatchNorm2d-44          [-1, 256, 57, 57]             512
# Convolution_Block-45          [-1, 256, 57, 57]               0
#              ReLU-46          [-1, 256, 57, 57]               0
#    Residual_Block-47          [-1, 256, 57, 57]               0
#            Conv2d-48          [-1, 128, 57, 57]          32,896
#       BatchNorm2d-49          [-1, 128, 57, 57]             256
# Convolution_Block-50          [-1, 128, 57, 57]               0
#              ReLU-51          [-1, 128, 57, 57]               0
#            Conv2d-52          [-1, 128, 29, 29]         147,584
#       BatchNorm2d-53          [-1, 128, 29, 29]             256
# Convolution_Block-54          [-1, 128, 29, 29]               0
#              ReLU-55          [-1, 128, 29, 29]               0
#            Conv2d-56          [-1, 512, 29, 29]          66,048
#       BatchNorm2d-57          [-1, 512, 29, 29]           1,024
# Convolution_Block-58          [-1, 512, 29, 29]               0
#            Conv2d-59          [-1, 512, 29, 29]         131,584
#       BatchNorm2d-60          [-1, 512, 29, 29]           1,024
# Convolution_Block-61          [-1, 512, 29, 29]               0
#              ReLU-62          [-1, 512, 29, 29]               0
#    Residual_Block-63          [-1, 512, 29, 29]               0
#            Conv2d-64          [-1, 128, 29, 29]          65,664
#       BatchNorm2d-65          [-1, 128, 29, 29]             256
# Convolution_Block-66          [-1, 128, 29, 29]               0
#              ReLU-67          [-1, 128, 29, 29]               0
#            Conv2d-68          [-1, 128, 29, 29]         147,584
#       BatchNorm2d-69          [-1, 128, 29, 29]             256
# Convolution_Block-70          [-1, 128, 29, 29]               0
#              ReLU-71          [-1, 128, 29, 29]               0
#            Conv2d-72          [-1, 512, 29, 29]          66,048
#       BatchNorm2d-73          [-1, 512, 29, 29]           1,024
# Convolution_Block-74          [-1, 512, 29, 29]               0
#              ReLU-75          [-1, 512, 29, 29]               0
#    Residual_Block-76          [-1, 512, 29, 29]               0
#            Conv2d-77          [-1, 128, 29, 29]          65,664
#       BatchNorm2d-78          [-1, 128, 29, 29]             256
# Convolution_Block-79          [-1, 128, 29, 29]               0
#              ReLU-80          [-1, 128, 29, 29]               0
#            Conv2d-81          [-1, 128, 29, 29]         147,584
#       BatchNorm2d-82          [-1, 128, 29, 29]             256
# Convolution_Block-83          [-1, 128, 29, 29]               0
#              ReLU-84          [-1, 128, 29, 29]               0
#            Conv2d-85          [-1, 512, 29, 29]          66,048
#       BatchNorm2d-86          [-1, 512, 29, 29]           1,024
# Convolution_Block-87          [-1, 512, 29, 29]               0
#              ReLU-88          [-1, 512, 29, 29]               0
#    Residual_Block-89          [-1, 512, 29, 29]               0
#            Conv2d-90          [-1, 128, 29, 29]          65,664
#       BatchNorm2d-91          [-1, 128, 29, 29]             256
# Convolution_Block-92          [-1, 128, 29, 29]               0
#              ReLU-93          [-1, 128, 29, 29]               0
#            Conv2d-94          [-1, 128, 29, 29]         147,584
#       BatchNorm2d-95          [-1, 128, 29, 29]             256
# Convolution_Block-96          [-1, 128, 29, 29]               0
#              ReLU-97          [-1, 128, 29, 29]               0
#            Conv2d-98          [-1, 512, 29, 29]          66,048
#       BatchNorm2d-99          [-1, 512, 29, 29]           1,024
# Convolution_Block-100          [-1, 512, 29, 29]               0
#             ReLU-101          [-1, 512, 29, 29]               0
#   Residual_Block-102          [-1, 512, 29, 29]               0
#           Conv2d-103          [-1, 256, 29, 29]         131,328
#      BatchNorm2d-104          [-1, 256, 29, 29]             512
# Convolution_Block-105          [-1, 256, 29, 29]               0
#             ReLU-106          [-1, 256, 29, 29]               0
#           Conv2d-107          [-1, 256, 15, 15]         590,080
#      BatchNorm2d-108          [-1, 256, 15, 15]             512
# Convolution_Block-109          [-1, 256, 15, 15]               0
#             ReLU-110          [-1, 256, 15, 15]               0
#           Conv2d-111         [-1, 1024, 15, 15]         263,168
#      BatchNorm2d-112         [-1, 1024, 15, 15]           2,048
# Convolution_Block-113         [-1, 1024, 15, 15]               0
#           Conv2d-114         [-1, 1024, 15, 15]         525,312
#      BatchNorm2d-115         [-1, 1024, 15, 15]           2,048
# Convolution_Block-116         [-1, 1024, 15, 15]               0
#             ReLU-117         [-1, 1024, 15, 15]               0
#   Residual_Block-118         [-1, 1024, 15, 15]               0
#           Conv2d-119          [-1, 256, 15, 15]         262,400
#      BatchNorm2d-120          [-1, 256, 15, 15]             512
# Convolution_Block-121          [-1, 256, 15, 15]               0
#             ReLU-122          [-1, 256, 15, 15]               0
#           Conv2d-123          [-1, 256, 15, 15]         590,080
#      BatchNorm2d-124          [-1, 256, 15, 15]             512
# Convolution_Block-125          [-1, 256, 15, 15]               0
#             ReLU-126          [-1, 256, 15, 15]               0
#           Conv2d-127         [-1, 1024, 15, 15]         263,168
#      BatchNorm2d-128         [-1, 1024, 15, 15]           2,048
# Convolution_Block-129         [-1, 1024, 15, 15]               0
#             ReLU-130         [-1, 1024, 15, 15]               0
#   Residual_Block-131         [-1, 1024, 15, 15]               0
#           Conv2d-132          [-1, 256, 15, 15]         262,400
#      BatchNorm2d-133          [-1, 256, 15, 15]             512
# Convolution_Block-134          [-1, 256, 15, 15]               0
#             ReLU-135          [-1, 256, 15, 15]               0
#           Conv2d-136          [-1, 256, 15, 15]         590,080
#      BatchNorm2d-137          [-1, 256, 15, 15]             512
# Convolution_Block-138          [-1, 256, 15, 15]               0
#             ReLU-139          [-1, 256, 15, 15]               0
#           Conv2d-140         [-1, 1024, 15, 15]         263,168
#      BatchNorm2d-141         [-1, 1024, 15, 15]           2,048
# Convolution_Block-142         [-1, 1024, 15, 15]               0
#             ReLU-143         [-1, 1024, 15, 15]               0
#   Residual_Block-144         [-1, 1024, 15, 15]               0
#           Conv2d-145          [-1, 256, 15, 15]         262,400
#      BatchNorm2d-146          [-1, 256, 15, 15]             512
# Convolution_Block-147          [-1, 256, 15, 15]               0
#             ReLU-148          [-1, 256, 15, 15]               0
#           Conv2d-149          [-1, 256, 15, 15]         590,080
#      BatchNorm2d-150          [-1, 256, 15, 15]             512
# Convolution_Block-151          [-1, 256, 15, 15]               0
#             ReLU-152          [-1, 256, 15, 15]               0
#           Conv2d-153         [-1, 1024, 15, 15]         263,168
#      BatchNorm2d-154         [-1, 1024, 15, 15]           2,048
# Convolution_Block-155         [-1, 1024, 15, 15]               0
#             ReLU-156         [-1, 1024, 15, 15]               0
#   Residual_Block-157         [-1, 1024, 15, 15]               0
#           Conv2d-158          [-1, 256, 15, 15]         262,400
#      BatchNorm2d-159          [-1, 256, 15, 15]             512
# Convolution_Block-160          [-1, 256, 15, 15]               0
#             ReLU-161          [-1, 256, 15, 15]               0
#           Conv2d-162          [-1, 256, 15, 15]         590,080
#      BatchNorm2d-163          [-1, 256, 15, 15]             512
# Convolution_Block-164          [-1, 256, 15, 15]               0
#             ReLU-165          [-1, 256, 15, 15]               0
#           Conv2d-166         [-1, 1024, 15, 15]         263,168
#      BatchNorm2d-167         [-1, 1024, 15, 15]           2,048
# Convolution_Block-168         [-1, 1024, 15, 15]               0
#             ReLU-169         [-1, 1024, 15, 15]               0
#   Residual_Block-170         [-1, 1024, 15, 15]               0
#           Conv2d-171          [-1, 256, 15, 15]         262,400
#      BatchNorm2d-172          [-1, 256, 15, 15]             512
# Convolution_Block-173          [-1, 256, 15, 15]               0
#             ReLU-174          [-1, 256, 15, 15]               0
#           Conv2d-175          [-1, 256, 15, 15]         590,080
#      BatchNorm2d-176          [-1, 256, 15, 15]             512
# Convolution_Block-177          [-1, 256, 15, 15]               0
#             ReLU-178          [-1, 256, 15, 15]               0
#           Conv2d-179         [-1, 1024, 15, 15]         263,168
#      BatchNorm2d-180         [-1, 1024, 15, 15]           2,048
# Convolution_Block-181         [-1, 1024, 15, 15]               0
#             ReLU-182         [-1, 1024, 15, 15]               0
#   Residual_Block-183         [-1, 1024, 15, 15]               0
#           Conv2d-184          [-1, 512, 15, 15]         524,800
#      BatchNorm2d-185          [-1, 512, 15, 15]           1,024
# Convolution_Block-186          [-1, 512, 15, 15]               0
#             ReLU-187          [-1, 512, 15, 15]               0
#           Conv2d-188            [-1, 512, 8, 8]       2,359,808
#      BatchNorm2d-189            [-1, 512, 8, 8]           1,024
# Convolution_Block-190            [-1, 512, 8, 8]               0
#             ReLU-191            [-1, 512, 8, 8]               0
#           Conv2d-192           [-1, 2048, 8, 8]       1,050,624
#      BatchNorm2d-193           [-1, 2048, 8, 8]           4,096
# Convolution_Block-194           [-1, 2048, 8, 8]               0
#           Conv2d-195           [-1, 2048, 8, 8]       2,099,200
#      BatchNorm2d-196           [-1, 2048, 8, 8]           4,096
# Convolution_Block-197           [-1, 2048, 8, 8]               0
#             ReLU-198           [-1, 2048, 8, 8]               0
#   Residual_Block-199           [-1, 2048, 8, 8]               0
#           Conv2d-200            [-1, 512, 8, 8]       1,049,088
#      BatchNorm2d-201            [-1, 512, 8, 8]           1,024
# Convolution_Block-202            [-1, 512, 8, 8]               0
#             ReLU-203            [-1, 512, 8, 8]               0
#           Conv2d-204            [-1, 512, 8, 8]       2,359,808
#      BatchNorm2d-205            [-1, 512, 8, 8]           1,024
# Convolution_Block-206            [-1, 512, 8, 8]               0
#             ReLU-207            [-1, 512, 8, 8]               0
#           Conv2d-208           [-1, 2048, 8, 8]       1,050,624
#      BatchNorm2d-209           [-1, 2048, 8, 8]           4,096
# Convolution_Block-210           [-1, 2048, 8, 8]               0
#             ReLU-211           [-1, 2048, 8, 8]               0
#   Residual_Block-212           [-1, 2048, 8, 8]               0
#           Conv2d-213            [-1, 512, 8, 8]       1,049,088
#      BatchNorm2d-214            [-1, 512, 8, 8]           1,024
# Convolution_Block-215            [-1, 512, 8, 8]               0
#             ReLU-216            [-1, 512, 8, 8]               0
#           Conv2d-217            [-1, 512, 8, 8]       2,359,808
#      BatchNorm2d-218            [-1, 512, 8, 8]           1,024
# Convolution_Block-219            [-1, 512, 8, 8]               0
#             ReLU-220            [-1, 512, 8, 8]               0
#           Conv2d-221           [-1, 2048, 8, 8]       1,050,624
#      BatchNorm2d-222           [-1, 2048, 8, 8]           4,096
# Convolution_Block-223           [-1, 2048, 8, 8]               0
#             ReLU-224           [-1, 2048, 8, 8]               0
#   Residual_Block-225           [-1, 2048, 8, 8]               0
# AdaptiveAvgPool2d-226           [-1, 2048, 1, 1]               0
#           Linear-227                   [-1, 21]          43,029
# ================================================================
# Total params: 23,577,621
# Trainable params: 23,577,621
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.59
# Forward/backward pass size (MB): 400.96
# Params size (MB): 89.94
# Estimated Total Size (MB): 491.49
# ----------------------------------------------------------------
